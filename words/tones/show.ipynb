# %%
tones = "0. <b>cheng</b>: ---\n1. <b>chēng</b>\n<i>counts: 8</i>: \n - [<i>837</i>] <b>称</b>: называть,  измерять,  соответствовать\n - [<i>1820</i>] <b>称为</b>: называться,  именоваться,  считаться\n - [<i>3428</i>] <b>名称</b>: название,  наименование,  титул\n - [<i>3955</i>] <b>撑</b>: поддерживать,  выдерживать,  терпеть\n - [<i>4272</i>] <b>支撑</b>: поддерживать,  опора,  выдерживать\n - [<i>4463</i>] <b>称号</b>: звание,  титул,  название\n - [<i>4664</i>] <b>称赞</b>: хвалить,  одобрять,  восхищаться\n - [<i>4858</i>] <b>称之为</b>: называть,  именовать,  определять\n2. <b>chéng</b>\n<i>counts: 50</i>: \n - [<i>133</i>] <b>成</b>: становиться,  достигать,  формировать\n - ***\n - [<i>322</i>] <b>城市</b>: город,  урбанизированная территория,  городская местность\n - [<i>356</i>] <b>工程</b>: проект,  строительство,  инженерное дело\n - [<i>449</i>] <b>成功</b>: успех,  достижение,  преуспеть\n - [<i>480</i>] <b>形成</b>: формировать,  образовывать,  складываться\n - [<i>527</i>] <b>过程</b>: процесс,  стадия,  процедура\n - [<i>544</i>] <b>完成</b>: завершить,  выполнить,  закончить\n - [<i>648</i>] <b>成立</b>: основать,  создать,  учредить\n - [<i>670</i>] <b>成绩</b>: результат,  достижение,  успеваемость\n - [<i>700</i>] <b>造成</b>: вызвать,  привести к,  создать\n - [<i>857</i>] <b>城</b>: город,  крепость,  стена\n - [<i>881</i>] <b>变成</b>: стать,  превратиться,  изменяться\n - [<i>923</i>] <b>程度</b>: степень,  уровень,  мера\n - [<i>936</i>] <b>成果</b>: результат,  достижение,  успех\n - [<i>1173</i>] <b>组成</b>: составлять,  формировать,  структура\n - [<i>1207</i>] <b>承认</b>: признавать,  соглашаться,  подтверждать\n - [<i>1214</i>] <b>成员</b>: участник,  член организации,  член семьи\n - [<i>1386</i>] <b>建成</b>: построить,  завершить строительство,  создать\n - [<i>1429</i>] <b>进程</b>: процесс,  ход,  этап\n - [<i>1491</i>] <b>成就</b>: достижение,  успех,  результат\n - [<i>1644</i>] <b>成本</b>: себестоимость,  издержки,  расходы\n - [<i>1687</i>] <b>达成</b>: достичь,  добиться,  договориться\n - [<i>1743</i>] <b>成长</b>: рост,  развитие,  взросление\n - [<i>1746</i>] <b>承担</b>: брать на себя,  нести ответственность,  выполнять обязанности\n - [<i>1870</i>] <b>成熟</b>: зрелый,  спелый,  опытный\n - [<i>1929</i>] <b>构成</b>: составлять,  формировать,  структура\n - [<i>2031</i>] <b>程序</b>: программа,  процедура,  порядок\n - [<i>2337</i>] <b>乘</b>: умножать,  ехать на транспорте,  воспользоваться случаем\n - [<i>2342</i>] <b>城镇</b>: город,  посёлок городского типа,  населённый пункт\n - [<i>2537</i>] <b>承诺</b>: обещание,  обязательство,  обязываться\n - [<i>2755</i>] <b>成效</b>: результат,  эффект,  успех\n - [<i>2894</i>] <b>呈</b>: представлять,  показывать,  проявлять\n - [<i>3029</i>] <b>程</b>: процесс,  этап,  степень\n - [<i>3213</i>] <b>继承</b>: наследовать,  продолжение,  передача\n - [<i>3300</i>] <b>呈现</b>: показывать,  проявлять,  отображать\n - [<i>3420</i>] <b>承受</b>: терпеть,  нести,  выносить\n - [<i>3520</i>] <b>城乡</b>: город,  деревня,  местность\n - [<i>3544</i>] <b>承包</b>: брать подряд,  арендовать,  обязательства\n - [<i>3545</i>] <b>课程</b>: курс,  предмет,  учебный план\n - [<i>3591</i>] <b>城里</b>: город,  внутри,  черта города\n - [<i>3599</i>] <b>成分</b>: состав,  компонент,  элемент\n - [<i>3655</i>] <b>赞成</b>: одобрять,  соглашаться,  поддерживать\n - [<i>3679</i>] <b>真诚</b>: искренний,  честный,  открытый\n - [<i>3681</i>] <b>县城</b>: уездный город,  административный центр,  центр\n - [<i>3727</i>] <b>成员国</b>: государство-член,  страна-член,  член организации\n - [<i>3945</i>] <b>当成</b>: считать,  воспринимать,  принимать\n - [<i>4383</i>] <b>组成部分</b>: компонент,  составная часть,  элемент\n - [<i>4549</i>] <b>历程</b>: путь,  этапы,  процесс развития\n - [<i>4790</i>] <b>工程师</b>: инженер,  конструктор,  специалист\n3. <b>chěng</b>: ---\n4. <b>chèng</b>: ---\n 0. <b>wei</b>: ---\n1. <b>wēi</b>\n<i>counts: 10</i>: \n - [<i>1446</i>] <b>紫薇</b>: лагерстремия,  китайская сирень,  Полярная звезда\n - [<i>1630</i>] <b>危险</b>: опасность,  риск,  угроза\n - [<i>1697</i>] <b>危机</b>: кризис,  опасность,  чрезвычайная ситуация\n - [<i>1837</i>] <b>微笑</b>: лёгкая улыбка,  улыбаться,  спокойная\n - [<i>1850</i>] <b>威胁</b>: угроза,  запугивать,  устрашать\n - [<i>2171</i>] <b>微</b>: маленький,  незначительный,  едва заметный\n - [<i>2906</i>] <b>微微</b>: слегка,  немного,  едва заметно\n - [<i>2923</i>] <b>威</b>: власть,  авторитет,  сила\n - [<i>2998</i>] <b>权威</b>: авторитет,  власть,  влияние\n - [<i>3224</i>] <b>危害</b>: вред,  опасность,  ущерб\n2. <b>wéi</b>\n<i>counts: 16</i>: \n - [<i>989</i>] <b>维护</b>: защищать,  поддерживать,  сохранять\n - [<i>1043</i>] <b>范围</b>: область,  границы,  сфера\n - [<i>1439</i>] <b>唯一</b>: единственный,  уникальный,  исключительный\n - [<i>1691</i>] <b>周围</b>: вокруг,  окружение,  окрестности\n - [<i>1869</i>] <b>围</b>: окружать,  обхватывать,  огораживать\n - [<i>2288</i>] <b>思维</b>: мышление,  размышление,  логика\n - [<i>2330</i>] <b>围绕</b>: окружать,  вращаться вокруг,  сосредоточиваться на\n - [<i>2339</i>] <b>维持</b>: поддерживать,  сохранять,  обеспечивать\n - [<i>2363</i>] <b>违法</b>: незаконный,  нарушать закон,  правонарушение\n - [<i>2705</i>] <b>违反</b>: нарушать,  противоречить,  идти вразрез\n - [<i>4158</i>] <b>包围</b>: окружать,  блокировать,  осаждать\n - [<i>4339</i>] <b>氛围</b>: атмосфера,  обстановка,  настроение\n - [<i>4431</i>] <b>维生素</b>: витамин,  витамины\n - [<i>4607</i>] <b>违背</b>: нарушать,  противоречить,  действовать вопреки\n - [<i>4626</i>] <b>惟一</b>: единственный,  уникальный,  исключительный\n - [<i>4902</i>] <b>维修</b>: ремонт,  обслуживание,  восстановление\n3. <b>wěi</b>\n<i>counts: 16</i>: \n - [<i>525</i>] <b>委员会</b>: комитет,  комиссия,  совет\n - [<i>1113</i>] <b>委员</b>: член комитета,  делегат,  уполномоченный\n - [<i>1216</i>] <b>伟大</b>: великий,  выдающийся,  грандиозный\n - [<i>1979</i>] <b>党委</b>: партийный комитет,  комсомольский орган,  комитет партии\n - [<i>2086</i>] <b>委员长</b>: председатель,  глава,  руководитель\n - [<i>2116</i>] <b>市委</b>: городской комитет,  горком\n - [<i>2252</i>] <b>省委</b>: провинциальный комитет КПК\n - [<i>2858</i>] <b>常委</b>: член Постоянного комитета,  постоянный,  представитель\n - [<i>3461</i>] <b>委屈</b>: обида,  несправедливость,  унижение\n - [<i>3743</i>] <b>委托</b>: поручение,  доверенность,  поручить\n - [<i>3857</i>] <b>政委</b>: политический комиссар,  политкомиссар,  политрук\n - [<i>4007</i>] <b>尾</b>: хвост,  конец,  задняя часть\n - [<i>4215</i>] <b>组委会</b>: оргкомитет,  группа организаторов,  комитет\n - [<i>4297</i>] <b>县委</b>: уездный комитет,  комитет партии,  партийный орган\n - [<i>4736</i>] <b>伟</b>: великий,  выдающийся,  грандиозный\n - [<i>4759</i>] <b>国务委员</b>: государственный советник,  член совета,  чиновник\n4. <b>wèi</b>\n<i>counts: 55</i>: \n - [<i>27</i>] <b>为</b>: быть,  делать,  для\n - [<i>114</i>] <b>因为</b>: потому что,  так как,  поскольку\n - [<i>119</i>] <b>位</b>: место,  позиция,  должность\n - [<i>169</i>] <b>认为</b>: считать,  полагать,  думать\n - ***\n - [<i>245</i>] <b>为了</b>: для,  ради,  с целью\n - [<i>276</i>] <b>作为</b>: в качестве,  действия,  поступки\n - [<i>346</i>] <b>为什么</b>: почему,  зачем,  по какой причине\n - [<i>474</i>] <b>单位</b>: организация,  учреждение,  подразделение\n - [<i>624</i>] <b>未</b>: не,  ещё не,  будущее\n - [<i>653</i>] <b>行为</b>: поведение,  поступок,  действие\n - [<i>677</i>] <b>地位</b>: положение,  статус,  место\n - [<i>794</i>] <b>以为</b>: думать,  предполагать,  ошибочно считать\n - [<i>882</i>] <b>所谓</b>: так называемый,  якобы,  упомянутый\n - [<i>969</i>] <b>未来</b>: будущее,  перспектива,  грядущее\n - [<i>1335</i>] <b>位置</b>: местоположение,  место,  позиция\n - [<i>1376</i>] <b>卫生</b>: гигиена,  санитария,  здравоохранение\n - [<i>1727</i>] <b>为主</b>: главный,  основной,  преимущественно\n - [<i>1820</i>] <b>称为</b>: называться,  именоваться,  считаться\n - [<i>1962</i>] <b>味</b>: вкус,  аромат,  привкус\n - [<i>2076</i>] <b>位于</b>: находиться,  располагаться,  быть расположенным\n - [<i>2118</i>] <b>喂</b>: алло,  кормить\n - [<i>2459</i>] <b>意味着</b>: означать,  значить,  подразумевать\n - [<i>2672</i>] <b>岗位</b>: должность,  рабочее место,  пост\n - [<i>2702</i>] <b>味道</b>: вкус,  запах,  аромат\n - [<i>2708</i>] <b>那位</b>: тот человек,  господин,  дама\n - [<i>2792</i>] <b>尚未</b>: ещё не,  пока не,  до сих пор не\n - [<i>2855</i>] <b>极为</b>: чрезвычайно,  крайне,  очень\n - [<i>2983</i>] <b>更为</b>: более,  ещё более,  в большей степени\n - [<i>3026</i>] <b>为期</b>: срок,  продолжительность,  на период\n - [<i>3066</i>] <b>卫星</b>: спутник,  искусственный спутник,  космический аппарат\n - [<i>3179</i>] <b>最为</b>: самый,  чрезвычайно,  наиболее\n - [<i>3203</i>] <b>为止</b>: до,  вплоть до,  ограничиваться\n - [<i>3215</i>] <b>安慰</b>: утешать,  поддержка,  успокаивать\n - [<i>3480</i>] <b>保卫</b>: защищать,  охранять,  оборонять\n - [<i>3643</i>] <b>为何</b>: почему,  зачем,  по какой причине\n - [<i>3676</i>] <b>各位</b>: все,  присутствующие,  коллеги\n - [<i>3747</i>] <b>较为</b>: сравнительно,  относительно,  довольно\n - [<i>3773</i>] <b>视为</b>: считать,  воспринимать,  принимать за\n - [<i>3973</i>] <b>分为</b>: делиться,  разделяться,  состоять\n - [<i>3983</i>] <b>学位</b>: степень,  диплом,  академический\n - [<i>4020</i>] <b>滋味</b>: вкус,  ощущение,  переживание\n - [<i>4063</i>] <b>胃</b>: желудок\n - [<i>4239</i>] <b>未能</b>: не смог,  не удалось,  быть не в состоянии\n - [<i>4360</i>] <b>列为</b>: классифицировать,  включить,  причислить\n - [<i>4405</i>] <b>慰问</b>: выразить сочувствие,  поддержку,  заботу\n - [<i>4437</i>] <b>从未</b>: никогда,  ни разу,  никогда прежде\n - [<i>4487</i>] <b>魏</b>: Вэй,  фамилия,  древнее царство\n - [<i>4489</i>] <b>可谓</b>: можно сказать,  можно назвать,  поистине\n - [<i>4592</i>] <b>未必</b>: не обязательно,  вряд ли,  не факт\n - [<i>4593</i>] <b>定位</b>: позиционирование,  определение местоположения,  геолокация\n - [<i>4729</i>] <b>到位</b>: быть на месте,  своевременный,  соответствовать\n - [<i>4858</i>] <b>称之为</b>: называть,  именовать,  определять\n - [<i>4875</i>] <b>为首</b>: возглавлять,  быть лидером,  стоять во главе\n - [<i>4954</i>] <b>座位</b>: место,  сиденье,  посадочное место"

print(tones)
# Out:
# 0. <b>cheng</b>: ---
# 1. <b>chēng</b>
# <i>counts: 8</i>:
#  - [<i>837</i>] <b>称</b>: называть,  измерять,  соответствовать
#  - [<i>1820</i>] <b>称为</b>: называться,  именоваться,  считаться
#  - [<i>3428</i>] <b>名称</b>: название,  наименование,  титул
#  - [<i>3955</i>] <b>撑</b>: поддерживать,  выдерживать,  терпеть
#  - [<i>4272</i>] <b>支撑</b>: поддерживать,  опора,  выдерживать
#  - [<i>4463</i>] <b>称号</b>: звание,  титул,  название
#  - [<i>4664</i>] <b>称赞</b>: хвалить,  одобрять,  восхищаться
#  - [<i>4858</i>] <b>称之为</b>: называть,  именовать,  определять
# 2. <b>chéng</b>
# <i>counts: 50</i>:
#  - [<i>133</i>] <b>成</b>: становиться,  достигать,  формировать
#  - ***
#  - [<i>322</i>] <b>城市</b>: город,  урбанизированная территория,  городская местность
#  - [<i>356</i>] <b>工程</b>: проект,  строительство,  инженерное дело
#  - [<i>449</i>] <b>成功</b>: успех,  достижение,  преуспеть
#  - [<i>480</i>] <b>形成</b>: формировать,  образовывать,  складываться
# ...

# %%
tones = "0. <b>cheng</b>: ---\n1. <b>chēng</b>\n<i>counts: 4</i>: \n - [<i>837</i>] <b>称</b>: называть,  измерять,  соответствовать\n - [<i>3955</i>] <b>撑</b>: поддерживать,  выдерживать,  терпеть\n2. <b>chéng</b>\n<i>counts: 47</i>: \n - [<i>133</i>] <b>成</b>: становиться,  достигать,  формировать\n - ***\n - [<i>322</i>] <b>城*</b>: ***\n - [<i>356</i>] <b>*程</b>: ***\n - [<i>857</i>] <b>城</b>: город,  крепость,  стена\n - [<i>1207</i>] <b>承*</b>: ***\n - [<i>2337</i>] <b>乘</b>: умножать,  ехать на транспорте,  воспользоваться случаем\n - [<i>2894</i>] <b>呈</b>: представлять,  показывать,  проявлять\n - [<i>3029</i>] <b>程</b>: процесс,  этап,  степень\n - [<i>3679</i>] <b>*诚</b>: ***\n3. <b>chěng</b>: ---\n4. <b>chèng</b>: ---\n 0. <b>wei</b>: ---\n1. <b>wēi</b>\n<i>counts: 10</i>: \n - [<i>1446</i>] <b>*薇</b>: ***\n - [<i>1630</i>] <b>危*</b>: ***\n - [<i>1837</i>] <b>微*</b>: ***\n - [<i>1850</i>] <b>威*</b>: ***\n - [<i>2171</i>] <b>微</b>: маленький,  незначительный,  едва заметный\n - [<i>2906</i>] <b>微微</b>: ***\n - [<i>2923</i>] <b>威</b>: власть,  авторитет,  сила\n2. <b>wéi</b>\n<i>counts: 10</i>: \n - [<i>989</i>] <b>维*</b>: ***\n - [<i>1043</i>] <b>*围</b>: ***\n - [<i>1439</i>] <b>唯*</b>: ***\n - [<i>1869</i>] <b>围</b>: окружать,  обхватывать,  огораживать\n - [<i>2363</i>] <b>违*</b>: ***\n3. <b>wěi</b>\n<i>counts: 12</i>: \n - [<i>525</i>] <b>委**</b>: ***\n - [<i>1216</i>] <b>伟*</b>: ***\n - [<i>4007</i>] <b>尾</b>: хвост,  конец,  задняя часть\n4. <b>wèi</b>\n<i>counts: 41</i>: \n - [<i>27</i>] <b>为</b>: быть,  делать,  для\n - [<i>119</i>] <b>位</b>: место,  позиция,  должность\n - ***\n - [<i>624</i>] <b>未</b>: не,  ещё не,  будущее\n - [<i>882</i>] <b>*谓</b>: ***\n - [<i>1376</i>] <b>卫*</b>: ***\n - [<i>1962</i>] <b>味</b>: вкус,  аромат,  привкус\n - [<i>2118</i>] <b>喂</b>: алло,  кормить\n - [<i>3215</i>] <b>*慰</b>: ***"


print(tones)
# Out:
# 0. <b>cheng</b>: ---
# 1. <b>chēng</b>
# <i>counts: 4</i>:
#  - [<i>837</i>] <b>称</b>: называть,  измерять,  соответствовать
#  - [<i>3955</i>] <b>撑</b>: поддерживать,  выдерживать,  терпеть
# 2. <b>chéng</b>
# <i>counts: 47</i>:
#  - [<i>133</i>] <b>成</b>: становиться,  достигать,  формировать
#  - ***
#  - [<i>322</i>] <b>城*</b>: ***
#  - [<i>356</i>] <b>*程</b>: ***
#  - [<i>857</i>] <b>城</b>: город,  крепость,  стена
#  - [<i>1207</i>] <b>承*</b>: ***
#  - [<i>2337</i>] <b>乘</b>: умножать,  ехать на транспорте,  воспользоваться случаем
#  - [<i>2894</i>] <b>呈</b>: представлять,  показывать,  проявлять
#  - [<i>3029</i>] <b>程</b>: процесс,  этап,  степень
#  - [<i>3679</i>] <b>*诚</b>: ***
# 3. <b>chěng</b>: ---
# 4. <b>chèng</b>: ---
#  0. <b>wei</b>: ---
# 1. <b>wēi</b>
# <i>counts: 10</i>:
#  - [<i>1446</i>] <b>*薇</b>: ***
#  - [<i>1630</i>] <b>危*</b>: ***
#  - [<i>1837</i>] <b>微*</b>: ***
#  - [<i>1850</i>] <b>威*</b>: ***
# ...
